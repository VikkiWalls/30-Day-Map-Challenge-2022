# %% [markdown]
# # 30 Day Map Challenge

# %% [markdown]
# ## Day 2 - Lines

# %% [markdown]
# Plan: Make a pretty map of rivers in the UK

# %%
import geopandas as gpd
import os
import pandas as pd

# %% [markdown]
# Setting the working directory

# %%
os.getcwd()
os.chdir("c:\\Users\\vicks\\OneDrive\\Data Science (not uni)\\Portfolio\\30 Day Map Challenge\\30 Day Map Challenge Data\\river data")

# %% [markdown]
# Importing the data - originally found on the [OS Website](https://osdatahub.os.uk/downloads/open/OpenRivers)

# %%
rivers = gpd.read_file("HydroNode.shp")

# %%
print(rivers.crs)
# Out:
# {'init': 'epsg:27700'}

# %%
watercourse = gpd.read_file("WatercourseLink.shp")

# %%
print(watercourse.crs)
# Out:
# {'init': 'epsg:27700'}

# %% [markdown]
# Building the map using geopandas

# %%
ax = rivers.plot(figsize=(50,50), color='black')
watercourse.plot(figsize=(50,50), cmap='GnBu' , ax=ax)
ax.set_facecolor("darkblue")
ax.set_axis_off();

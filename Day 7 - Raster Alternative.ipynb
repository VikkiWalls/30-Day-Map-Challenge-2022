# %% [markdown]
# # 30 Day Map Challenge

# %% [markdown]
# ## Day 7 - Raster

# %% [markdown]
# Plan: Map the mountains around Mafadi on the South Africa/Lesotho border using DEM files

# %% [markdown]
# Largely following the Making Sense Remotely [tutorial](https://youtu.be/5dDZeEXws9Q)

# %% [markdown]
# Raster DEM was clipped using the QGIS software

# %%
import matplotlib.pyplot as plt
import os
import subprocess

from osgeo import gdal

# %% [markdown]
# Setting the working directory

# %%
os.getcwd()
os.chdir("c:\\Users\\vicks\\OneDrive\\Data Science (not uni)\\Portfolio\\30 Day Map Challenge\\30 Day Map Challenge Data\\Raster")

# %% [markdown]
# Building a shell command to compute the DEM slope into a new file

# %%
slpcmd = "gdaldem slope MafadiClip.tif slope.tif -compute_edges"

# %% [markdown]
# Running the command

# %%
os.system(slpcmd)
# Out:
# 0

# %% [markdown]
# Building an array of the slope data

# %%
slp = gdal.Open("slope.tif")

# %%
slpArray = slp.GetRasterBand(1).ReadAsArray()

# %% [markdown]
# Visualising the array

# %%
plt.figure(figsize = (20,20))
plt.imshow(slpArray, cmap = "cubehelix")
plt.colorbar()
plt.title("Slope Plot ", fontsize = 40, pad='40.0')
plt.show()

# %% [markdown]
# Building a shell command to compute the DEM aspect into a new file

# %%
aspcmd = "gdaldem aspect MafadiClip.tif aspect.tif -compute_edges"

# %% [markdown]
# Running the command

# %%
os.system(aspcmd)
# Out:
# 0

# %% [markdown]
# Building an array of the aspect data

# %%
asp = gdal.Open("aspect.tif")

# %%
aspArray = asp.GetRasterBand(1).ReadAsArray()

# %% [markdown]
# Visualising the array

# %%
plt.figure(figsize = (20,20))
plt.imshow(aspArray, cmap = "cubehelix")
plt.colorbar()
plt.title("Aspect Plot ", fontsize = 40, pad='40.0')
plt.show()

# %% [markdown]
# Building a shell command to compute the DEM hillshade into a new file

# %%
hlshdcmd = "gdaldem hillshade MafadiClip.tif hillshade.tif -compute_edges"

# %% [markdown]
# Running the command

# %%
os.system(hlshdcmd)
# Out:
# 0

# %% [markdown]
# Building an array of the hillshade data

# %%
hlshd = gdal.Open("hillshade.tif")

# %%
hlshdArray = hlshd.GetRasterBand(1).ReadAsArray()

# %% [markdown]
# Visualising the array

# %%
plt.figure(figsize = (20,20))
plt.imshow(hlshdArray, cmap = "viridis")
plt.colorbar()
plt.title("Hillshade Plot ", fontsize = 40, pad='40.0', color = 'green')
plt.show()
